да в Харькове; Коварный Турагент; MirFactov - все самое интересное!; послание; I ♡ ART; My Mind; One Million Scarlet Roses; Factura - блог | Саморазвитие; Циник; Betraveler | Добро пожаловать на Землю; Свадебный ФОТОГРАФ Александр Поляков; М.; Wow! - нестандартный журнал; Кто не был студентом - тому не понять...; B e a u t é | Территория вдохновения; Больше, чем фото; Правильное Питание | Программы Тренировок; Бизнес цитатник; 40 КГ; Say 13 - Музыка 2024; Scie
# ...

# %%
import pandas as pd
user_new = pd.read_parquet("/kaggle/input/user-new-updated/user_new_updated.parquet")

# %%
group = pd.read_parquet("/kaggle/input/forgroup/group_table.parquet")

# %%
# Агрегация названий групп
group_names = group.groupby('user_id')['name'].apply(lambda names: '; '.join(names.dropna().str.strip())).reset_index()
group_names.rename(columns={'name': 'groups_names'}, inplace=True)

# Агрегация описаний групп
group_descriptions = group.groupby('user_id')['description'].apply(lambda descs: '; '.join(descs.dropna().str.strip())).reset_index()
group_descriptions.rename(columns={'description': 'groups_descriptions'}, inplace=True)

# Объединение агрегаций в одну таблицу
groups_aggregated = pd.merge(group_names, group_descriptions, on='user_id', how='outer')


# Объединение с user_new
user_new = user_new.merge(groups_aggregated, left_on="user_id", right_on="user_id", how='left')

# %%
groups_aggregated.head()
# Out:
#    user_id                                       groups_names  \
# 0        2  W Λ R; Интересный Таиланд /interesting Thailan...
# 1        3  Bikini Bottom; Koala sushi доставка sushi roll...
# 2        4  Студенческий Совет ИББМ | ТАРАКАШКИНЫ НОВОСТИ;...
# 3        5  ЧП ЛЫСЬВА; МАША ИЩЕТ! Самые позитивные распако...
# 4        6  Peach beauty; Фенечка | Красота своими руками;...
#
#                                  groups_descriptions
# 0  #WAR_music - музыка\n#WAR_look - луки\n#WAR_gi...
# 1  Всё расписание и навигация доступны тут:\n[htt...
# 2  Всё, чем живёт студенческий совет самого зелён...
# 3  Это сообщество для того, чтобы освещать происш...
# 4  Рады видеть вас, красавицы и красавцы! Здесь к...

# %%
user_new.head()
# Out:
#        vk_id first_name  last_name birth_date   age  user_id  avg_photo_likes  \
# 0  304375450    Алексей     Купцов   1.1.2007  17.0        1              NaN
# 1  664945617     นางฟ้า  ธิดาซาตาน   1.1.2007  17.0        2        35.714286
# 2  381637103   Виктория    Рознина   1.1.2007  17.0        3        46.000000
# 3  260892289   Вероника   Малышева   1.1.2007  17.0        4        77.571429
# 4  129110414      Ольга   Никитина   1.1.2007  17.0        5        25.777778
#
#    photo_count  post_count_owner  post_count_friend  post_count_delete  \
# 0          NaN               NaN                NaN                NaN
# 1          7.0               5.0               15.0               14.0
# 2          2.0               7.0                NaN                NaN
# 3          7.0              17.0                NaN                NaN
# 4         18.0               3.0               17.0                NaN
#
# ...

# %%
def aggregate_user_data(user_id: int, data: pd.DataFrame) -> str:
    user = data.loc[data['id'] == user_id]
    if user.empty:
        return ""
    user = user.iloc[0]

    # Основная информация
    first_name = user.get('first_name', 'Не указано')
    last_name = user.get('last_name', 'Не указано')
    birth_date = user.get('birth_date', 'Не указана')
    age = user.get('age', 'Не указан')
    average_likes_photos = user.get('avg_photo_likes', 'Нет данных')
    average_likes_posts = user.get('avg_post_likes', 'Нет данных')  # Убедитесь, что этот столбец существует
    friends_count = user.get('friend_count', 'Нет данных')
    posts_count_owner = user.get('post_count_owner', 0)
    posts_count_friend = user.get('post_count_friend', 0)
    posts_count_delete = user.get('post_count_delete', 0)
    group_count = user.get('group_count', 0)
    anon_pab = user.get('anon_pab', 0)
    groups_names = user.get('groups_names', 'Нет сообществ.')
    groups_descriptions = user.get('groups_descriptions', '')
    bio_text = user.get('bio_text', 'Нет биографии.')
    posts_text = user.get('posts_text', 'Нет публикаций.')

    # Друзья
    # Предполагается, что информация о друзьях собирается отдельно или хранится в виде агрегированных данных
    # Здесь можно добавить дополнительную обработку, если доступна

    # Форматирование итоговой строки
    summary = (
        ""
        f"### Информация о пользователе VKID: {user_id}\n\n"
        f"**Имя:** {first_name[:10]} {last_name[:10]}\n"
        f"**Возраст:** {age}\n"
        f"**Дата рождения:** {birth_date[:10]}\n"
        f"**Количество друзей:** {friends_count}\n"
        f"**Количество групп:** {group_count}\n"
        f"**Анонимные группы/Паблики:** {anon_pab}\n"
        f"**Названия групп:** {groups_names[:100]}\n"
        f"**Описание групп:** {groups_descriptions[:100]}\n"
        f"**Биография:** {bio_text[:10]}\n"
        f"**Количество фотографий:** {user.get('photo_count', 'Нет данных')}\n"
        f"**Среднее количество лайков на фотографиях:** {average_likes_photos}\n"
        f"**Количество постов от владельца:** {posts_count_owner}\n"
        f"**Количество постов от друзей:** {posts_count_friend}\n"
        f"**Количество удаленных постов:** {posts_count_delete}\n"
        f"**Среднее количество лайков на постах:** {average_likes_posts}\n"
        f"**Публикации пользователя:**\n{posts_text[:100]}\n"
    )

    return summary

# %%
import pandas as pd
import json

targat = ["1ЭАР", "1ЭЧР", "1ИАР", "1ИЧР", "1ИЧГ", "1ЭЧГ", "1ИАГ", "1ЭАГ", "2ЭАР", "2ЭЧР", "2ИАР", "2ИЧР", "2ИЧГ", "2ЭЧГ", "2ИАГ", "2ЭАГ", "3ЭАР", "3ЭЧР", "3ИАР", "3ИЧР", "3ИЧГ", "3ЭЧГ", "3ИАГ", "3ЭАГ"]
category_mapping = {el:{"Экстраверт":1 if "Э" in el else 0, "Аналитик":1 if "А" in el else 0,"Ригидный":1 if "Р" in el else 0,} for el in targat}

# %%
# !pip install -U easynmt

# %%
from easynmt import EasyNMT
model = EasyNMT('opus-mt', device=0)

# %%
from transformers import pipeline
zeroshot_classifier = pipeline("zero-shot-classification", model="MoritzLaurer/deberta-v3-large-zeroshot-v1.1-all-33", device=-1)
for idx, row in user_new[~user_new["category"].isna()].iterrows():
  user_id = row['id']
  category_code = row['category']
  if category_code not in category_mapping:
    continue  # Пропустить, если категория не в сопоставлении
  labels = category_mapping[category_code]
  user_info = aggregate_user_data(user_id, user_new)
  user_info = model.translate(user_info, target_lang='en')
  user_score = row["post_count_friend"]
  hypothesis_template = "This person is {}"
  classes_verbalised = ["extrovert", "introvert and more passive in social network"]
  output = zeroshot_classifier(user_info, classes_verbalised, hypothesis_template=hypothesis_template, multi_label=False)
  print(labels["Экстраверт"], user_score, output['labels'], output['scores'])

# %%
user_new = pd.read_parquet('/kaggle/input/usernew/user_new.parquet')

# %%
user_new["embed_results"] = pd.NA

# %%
user_new
# Out:
#          id      vk_id  first_name      last_name birth_date   age  \
# 0         2  664945617      นางฟ้า      ธิดาซาตาน   1.1.2007  17.0
# 1         6   11061275     Роксана       Варданян   1.1.2007  17.0
# 2        16   17127708       Артем       Ткаченко   1.1.2007  17.0
# 3        47   97024915      Сергей         Белоус   1.1.2007  17.0
# 4        48  305039607    Светлана         Салова   1.1.2007  17.0
# ...     ...        ...         ...            ...        ...   ...
# 2777  99736  144906315      Никита         Осипов  29.1.2005  19.0
# 2778  99742  300488423     Тимофей    Солдатенков  29.1.2005  19.0
# 2779  99749  498949700  Александра  Вальчиковская  29.1.2005  19.0
# 2780  99755  334203703      Максим        Голубев  29.1.2005  19.0
# 2781  99761  505137620        Вера        Донских  29.1.2005  19.0
#
#       friend_count  avg_photo_likes  photo_count  post_count_owner  \
# 0             1164        35.714286            7                 5
# ...

# %%
# !pip install tqdm
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# ...

# %%
from tqdm import tqdm

# %%
from transformers import pipeline
classifier = pipeline("zero-shot-classification", model="MoritzLaurer/mDeBERTa-v3-base-mnli-xnli", device=0)
candidate_labels = [
    "Sports",
    "Music",
    "Art",
    "Technology",
    "Travel",
    "Education",
    "Health",
    "Erotics",
    "Hobbies",
    "Business",
    "Politics",
    "Violence",
    "Crime",
    "Extremism",
    "Entertainment",
    "Environment"
]
# candidate_labels = [f"Group about {el}" for el in candidate_labels]

# %%
# !pip install sentence-transformers
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.2/255.2 kB 4.0 MB/s eta 0:00:00a 0:00:01
# ...

# %%
from sentence_transformers import SentenceTransformer, util

model = SentenceTransformer('sergeyzh/rubert-tiny-turbo', device=0)

# %%
encoded_labels = model.encode(candidate_labels, convert_to_tensor=True)

# Функция для вычисления разнообразия
def calculate_diversity(embeddings):
    if len(embeddings) <= 1:
        return 0.0
    # Вычисляем матрицу косинусных расстояний
    cosine_sim = util.cos_sim(embeddings, embeddings)
    # Избавляемся от диагонали (расстояние самого себя)
    mask = ~torch.eye(len(embeddings), dtype=torch.bool).to(device=0)
    cosine_sim = cosine_sim.masked_select(mask).reshape(len(embeddings), -1)
    # Усредняем расстояния
    diversity = cosine_sim.mean().item()
    return diversity
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# !python -m spacy download ru_core_news_sm
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 72.0 MB/s eta 0:00:0000:0100:01
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 63.0 MB/s eta 0:00:0000:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 58.4 MB/s eta 0:00:0000:0100:01
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_sm')

# %%
import spacy
import re

# Загрузка языковых моделей
try:
    nlp_en = spacy.load('en_core_web_sm')
except OSError:
    print("Модель en_core_web_sm не найдена. Установите её с помощью команды:")
    print("python -m spacy download en_core_web_sm")
    raise

try:
    nlp_ru = spacy.load('ru_core_news_sm')
except OSError:
    print("Модель ru_core_news_sm не найдена. Установите её с помощью команды:")
    print("python -m spacy download ru_core_news_sm")
    raise

def clean_and_lemmatize(text, lang='ru'):
    """
    Очищает и лемматизирует текст.
    
    :param text: Исходный текст.
    :param lang: Язык текста ('en' для английского, 'ru' для русского).
    :return: Лемматизированный текст.
    """
    # Удаление специальных символов и приведение к нижнему регистру
    text = re.sub(r'[^\w\s]', '', text)
    text = text.lower()
    
    # Выбор модели в зависимости от языка
    if lang == 'en':
        doc = nlp_en(text)
    elif lang == 'ru':
        doc = nlp_ru(text)
    else:
        raise ValueError("Поддерживаемые языки: 'en' для английского и 'ru' для русского.")
    
    # Лемматизация и удаление стоп-слов
    lemmas = [token.lemma_ for token in doc if not token.is_stop and token.is_alpha]
    
    return ' '.join(lemmas)

# %%
import torch
i = 0
for idx, row in tqdm(user_new.iterrows(), total=user_new.shape[0]):
    i += 1
    user_id = row['user_id']
    if type(row['groups_names']) != str:
        continue
    groups = row['groups_names'].split('; ')[:5]  # Берём первые 5 групп
    if not groups:
        user_new.at[idx, "embed_results"] = {
            "categories": [],
            "diversity": 0.0
        }
        continue

    # Очистка и лемматизация названий групп
    processed_groups = [clean_and_lemmatize(f"Группа под названием {group}") for group in groups]
    
    # Кодирование групп
    group_embeddings = model.encode(processed_groups, convert_to_tensor=True)

    # Для хранения топ-3 категорий для каждой группы
    top_categories = []

    for group_embedding in group_embeddings:
        # Вычисляем косинусное сходство с категориями
        cosine_scores = util.cos_sim(group_embedding, encoded_labels)[0]
        # Находим топ-3 индекса категорий с наибольшим сходством
        top_indices = torch.topk(cosine_scores, k=3).indices
        # Получаем названия категорий
        top_cat = [candidate_labels[idx] for idx in top_indices]
        top_categories.append(top_cat)
    
    # Усреднение эмбеддингов групп
    avg_group_embedding = torch.mean(group_embeddings, dim=0)

    # Max Pooling по всем эмбеддингам групп
    max_pooled_embedding, _ = torch.max(group_embeddings, dim=0)

    # Вычисление разнообразия
    diversity = calculate_diversity(group_embeddings) if len(group_embeddings) > 1 else 0.0

    # Сохранение результатов
    user_new.at[idx, "embed_results"] = {
        "categories": top_categories,
        "diversity": diversity,
        "avg_embedding": avg_group_embedding.cpu().numpy().tolist(),
        "max_pooled_embedding": max_pooled_embedding.cpu().numpy().tolist()
    }
    if i%400 == 0:
        user_new.to_parquet('user_temp_results.parquet', index=False)

# Пример сохранения результатов
user_new.to_parquet('user_results.parquet', index=False)

# %%
user_new.loc[1]["embed_results"]
# Out:
# {'categories': [['Technology', 'Business', 'Erotics'],
#   ['Technology', 'Travel', 'Extremism'],
#   ['Erotics', 'Entertainment', 'Violence'],
#   ['Technology', 'Extremism', 'Environment'],
#   ['Erotics', 'Extremism', 'Health']],
#  'diversity': 0.8091629147529602,
#  'avg_embedding': [-0.0019352138042449951,
#   0.0077677443623542786,
#   0.03562569618225098,
#   -0.0033371690660715103,
#   0.009126567281782627,
#   0.007908386178314686,
#   -0.03290925547480583,
#   -0.02187339961528778,
#   -0.04543175920844078,
#   0.013923140242695808,
#   0.00901078898459673,
#   0.0017066336004063487,
#   -0.019766289740800858,
#   0.01729764975607395,
#   0.019477158784866333,
#   0.036710672080516815,
#   -0.026170318946242332,
#   0.05981830880045891,
#   0.011253963224589825,
#   0.04770172759890556,
#   0.022288242354989052,
#   -0.022639555856585503,
#   0.006315904203802347,
#   -0.006039233412593603,
#   0.020680133253335953,
#   -0.014457568526268005,
#   0.0170277189463377,
# ...

# %%
for idx, row in tqdm(user_new.iterrows()):
    user_id = row['id']
    sentences = row['groups_names'].split('; ')[:5]
    sentences = [clean_and_lemmatize(f"Группа под названием {el}") for el in sentences] 
    embeddings = model.encode(sentences)

# %%
for_safety = user_new.copy()

# %%
group = pd.read_parquet('/kaggle/input/forgroup/group_table.parquet')

# %%
# Определение IQR
Q1 = user_new['friend_count'].quantile(0.25)
Q3 = user_new['friend_count'].quantile(0.85)
IQR = Q3 - Q1

# Верхняя граница по IQR
upper_bound_IQR = Q3 + 1.5 * IQR

print(f"Upper bound by IQR: {upper_bound_IQR}")

# Фильтрация данных
filtered_IQR = user_new[user_new['friend_count'] <= upper_bound_IQR]

print(f"Number of rows after IQR filtering: {len(filtered_IQR)}")
filtered_IQR
# Out:
# Upper bound by IQR: 312.0
# Number of rows after IQR filtering: 26148
#            vk_id first_name  last_name birth_date   age  user_id  \
# 0      304375450    Алексей     Купцов   1.1.2007  17.0        1
# 2      381637103   Виктория    Рознина   1.1.2007  17.0        3
# 3      260892289   Вероника   Малышева   1.1.2007  17.0        4
# 4      129110414      Ольга   Никитина   1.1.2007  17.0        5
# 6      460983785      Диана  Антоненко   1.1.2007  17.0        7
# ...          ...        ...        ...        ...   ...      ...
# 27235  448095161     Андрей   Миренков  29.1.2005  19.0    99767
# 27236  462272170      Artem     Volkov  29.1.2005  19.0    99768
# 27237  441298535       Иван   Боднарюк  29.1.2005  19.0    99769
# 27238  277412011  Александр      Галай  29.1.2005  19.0    99770
# 27239  271781035       Юрий  Поддубный  29.1.2005  19.0    99771
#
#        avg_photo_likes  photo_count  post_count_owner  post_count_friend  \
# ...

# %%
filtered_IQR["friend_count"] = filtered_IQR["friend_count"].apply(lambda x: None if x==-1 else x)
filtered_IQR
# Out:
# /tmp/ipykernel_30/121819939.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_IQR.loc["friend_count"] = filtered_IQR["friend_count"].apply(lambda x: None if x==-1 else x)
#                   vk_id first_name  last_name birth_date   age  user_id  \
# 0             304375450    Алексей     Купцов   1.1.2007  17.0      1.0
# 2             381637103   Виктория    Рознина   1.1.2007  17.0      3.0
# 3             260892289   Вероника   Малышева   1.1.2007  17.0      4.0
# 4             129110414      Ольга   Никитина   1.1.2007  17.0      5.0
# 6             460983785      Диана  Антоненко   1.1.2007  17.0      7.0
# ...                 ...        ...        ...        ...   ...      ...
# 27236         462272170      Artem     Volkov  29.1.2005  19.0  99768.0
# ...

# %%
photodata = pd.read_parquet("/kaggle/input/photodata/ph_c_dataset.parquet")

# %%
photodata.head()
# Out:
#    id  user_id                                            igm2txt  \
# 0   1        2   person in a protective suit and mask sitting ...
# 1   2        2                               nurse wearing a mask
# 2   3        2                   person ' s hand holding a camera
# 3   4        2          person ' s butt with the word cered on it
# 4   5        2                doctor examining a patient ' s knee
#
#                                                  url  like_count  \
# 0  https://sun9-44.userapi.com/s/v1/ig2/oORXcNP6D...          18
# 1  https://sun9-71.userapi.com/s/v1/ig2/evUGoA8RF...         152
# 2  https://sun9-41.userapi.com/s/v1/ig2/JWFmarLza...          14
# 3  https://sun9-24.userapi.com/s/v1/ig2/uWFCQMp8n...          25
# 4  https://sun9-66.userapi.com/s/v1/ig2/P3h58YKeH...          27
#
#                        predicted_top_categories  \
# 0                       [health, food, origami]
# 1  [beauty of appearance, sculpture, anonymous]
# ...

# %%
average_distance_df = photodata.groupby('user_id')['average_distance'].first().reset_index()

# Способ 2: Используя drop_duplicates и сохраняя первую запись
# average_distance_df = photodata[['user_id', 'average_distance']].drop_duplicates(subset='user_id')

# Шаг 2: Объединение user_new с агрегированным DataFrame по user_id
user_new = user_new.merge(average_distance_df, on='user_id', how='left')

# Теперь в user_new появилась колонка 'average_distance' с соответствующими значениями из photodata

# (Опционально) Шаг 3: Проверка на наличие пропущенных значений после объединения
missing_values = user_new['average_distance'].isnull().sum()
if missing_values > 0:
    print(f"Внимание: {missing_values} записей не имеют значения 'average_distance'.")
    # Здесь можно решить, как обработать пропущенные значения, например, заполнить средним значением
    # user_new['average_distance'].fillna(user_new['average_distance'].mean(), inplace=True)
# Out:
# Внимание: 10888 записей не имеют значения 'average_distance'.

# %%
user_new['average_distance'].fillna(0, inplace=True)

# %%
user_new["friend_count"] = user_new["friend_count"].apply(lambda x: None if x==-1 else x)

# %%
import numpy as np

# Среднее и стандартное отклонение для правила 3-х сигм
mean_friend_count = user_new[user_new["friend_count"].isna()]['avg_photo_likes'].mean()
std_friend_count = user_new[user_new["friend_count"].isna()]['avg_photo_likes'].std()

# Среднее и стандартное отклонение для правила 3-х сигм 2
mean_friend_count2 = user_new[~user_new["friend_count"].isna()]['like_friend_ratio'].mean()
std_friend_count2 = user_new[~user_new["friend_count"].isna()]['like_friend_ratio'].std()

# Верхняя граница по правилу 3-х сигм
upper_bound_3sigma = mean_friend_count + 3 * std_friend_count

# Верхняя граница по правилу 3-х сигм 2
upper_bound_3sigma2 = mean_friend_count2 + 3 * std_friend_count2


print(f"Upper bound by 3-sigma rule: {upper_bound_3sigma}")
print(f"Upper bound by 3-sigma rule2: {upper_bound_3sigma2}")

# Фильтрация данных
filtered_3sigma_with_nan = user_new[user_new["friend_count"].isna()].reset_index()
filtered_3sigma_without_nan = user_new[~user_new["friend_count"].isna()].reset_index()

filtered_3sigma_with_nan = filtered_3sigma_with_nan[filtered_3sigma_with_nan['avg_photo_likes'] <= upper_bound_3sigma].reset_index()
filtered_3sigma_without_nan = filtered_3sigma_without_nan[filtered_3sigma_without_nan['like_friend_ratio'] <= upper_bound_3sigma2].reset_index()


# Объединение результатов
all_filtered_3sigma = pd.concat([filtered_3sigma_with_nan, filtered_3sigma_without_nan])

print(f"Number of rows after 3-sigma filtering: {len(all_filtered_3sigma)}")
# Out:
# Upper bound by 3-sigma rule: 5439.977029293548
# Upper bound by 3-sigma rule2: 119.76345364075445
# Number of rows after 3-sigma filtering: 22069

# %%
user_new = all_filtered_3sigma
user_new.drop(columns=["level_0","index"], inplace=True)
user_new.head(1)
# Out:
#        vk_id first_name  last_name birth_date   age  user_id  avg_photo_likes  \
# 0  379798774      Елена  Кумшацкая   1.1.2007  17.0       10         2.666667
#
#    photo_count  post_count_owner  post_count_friend  post_count_delete  \
# 0          3.0               1.0               19.0                4.0
#
#    group_count  anon_pab  diff_city_count  friend_count  like_friend_ratio  \
# 0          NaN       NaN              NaN           NaN                NaN
#
#   groups_names groups_descriptions embed_results  average_distance
# 0          NaN                 NaN          <NA>          0.944907

# %%
user_new["avg_photo_likes"] = user_new["avg_photo_likes"].fillna(0)
user_new["photo_count"] = user_new["photo_count"].fillna(0)
user_new["post_count_owner"] = user_new["post_count_owner"].fillna(0)
user_new["post_count_friend"] = user_new["post_count_friend"].fillna(0)
user_new["post_count_delete"] = user_new["post_count_delete"].fillna(0)
user_new["friend_count"] = user_new["friend_count"].fillna(-30)

user_new.fillna(-0.001, inplace=True)
user_new.drop("like_friend_ratio", axis=1, inplace=True)
user_new
# Out:
#            vk_id first_name   last_name birth_date   age  user_id  \
# 0      379798774      Елена   Кумшацкая   1.1.2007  17.0       10
# 1      133343174   Анатолий     Голубец   1.1.2007  17.0       29
# 2      164421917       Маша    Заверуха   1.1.2007  17.0      101
# 3      476302530       Дина     Аверина   1.1.2007  17.0      154
# 4      311097298       Саня     Фёдоров   1.1.2007  17.0      326
# ...          ...        ...         ...        ...   ...      ...
# 21115  505137620       Вера     Донских  29.1.2005  19.0    99761
# 21116  495644176      Захар   Сильченко  29.1.2005  19.0    99762
# 21117  256485116       Vika    Coroleva  29.1.2005  19.0    99763
# 21118  390326578     Михаил  Овчинников  29.1.2005  19.0    99764
# 21119  441298535       Иван    Боднарюк  29.1.2005  19.0    99769
#
#        avg_photo_likes  photo_count  post_count_owner  post_count_friend  \
# 0             2.666667          3.0               1.0               19.0
# ...

# %%
user_new = user_new[~user_new["embed_results"].isna()]
# Out:
#            vk_id first_name   last_name birth_date   age  user_id  \
# 1      133343174   Анатолий     Голубец   1.1.2007  17.0       29
# 2      164421917       Маша    Заверуха   1.1.2007  17.0      101
# 3      476302530       Дина     Аверина   1.1.2007  17.0      154
# 4      311097298       Саня     Фёдоров   1.1.2007  17.0      326
# 5      261985066     Матвей    Маркелов   2.1.2007  17.0      344
# ...          ...        ...         ...        ...   ...      ...
# 21115  505137620       Вера     Донских  29.1.2005  19.0    99761
# 21116  495644176      Захар   Сильченко  29.1.2005  19.0    99762
# 21117  256485116       Vika    Coroleva  29.1.2005  19.0    99763
# 21118  390326578     Михаил  Овчинников  29.1.2005  19.0    99764
# 21119  441298535       Иван    Боднарюк  29.1.2005  19.0    99769
#
#        avg_photo_likes  photo_count  post_count_owner  post_count_friend  \
# 1            25.000000          4.0               NaN                1.0
# ...

# %%
user_new
# Out:
#            vk_id first_name   last_name birth_date   age  user_id  \
# 0      379798774      Елена   Кумшацкая   1.1.2007  17.0       10
# 1      133343174   Анатолий     Голубец   1.1.2007  17.0       29
# 2      164421917       Маша    Заверуха   1.1.2007  17.0      101
# 3      476302530       Дина     Аверина   1.1.2007  17.0      154
# 4      311097298       Саня     Фёдоров   1.1.2007  17.0      326
# ...          ...        ...         ...        ...   ...      ...
# 21115  505137620       Вера     Донских  29.1.2005  19.0    99761
# 21116  495644176      Захар   Сильченко  29.1.2005  19.0    99762
# 21117  256485116       Vika    Coroleva  29.1.2005  19.0    99763
# 21118  390326578     Михаил  Овчинников  29.1.2005  19.0    99764
# 21119  441298535       Иван    Боднарюк  29.1.2005  19.0    99769
#
#        avg_photo_likes  photo_count  post_count_owner  post_count_friend  \
# 0             2.666667          3.0               1.0               19.0
# ...

# %%
user_new = user_new[user_new["embed_results"]!=-0.001]

# %%
features = user_new.drop(columns=["first_name", "last_name", "birth_date", "age", "user_id", "avg_photo_likes", "photo_count", "post_count_owner", "post_count_friend", "post_count_delete", "group_count", "anon_pab", "diff_city_count", "friend_count", "groups_names", "groups_descriptions"])

# %%
features
# Out:
#            vk_id                                      embed_results  \
# 1      133343174  {'categories': [['Extremism', 'Environment', '...
# 2      164421917  {'categories': [['Hobbies', 'Erotics', 'Enviro...
# 3      476302530  {'categories': [['Hobbies', 'Erotics', 'Entert...
# 4      311097298  {'categories': [['Education', 'Entertainment',...
# 5      261985066  {'categories': [['Politics', 'Environment', 'V...
# ...          ...                                                ...
# 21115  505137620  {'categories': [['Education', 'Erotics', 'Tech...
# 21116  495644176  {'categories': [['Erotics', 'Extremism', 'Envi...
# 21117  256485116  {'categories': [['Education', 'Erotics', 'Busi...
# 21118  390326578  {'categories': [['Extremism', 'Erotics', 'Crim...
# 21119  441298535  {'categories': [['Business', 'Extremism', 'Ero...
#
#        average_distance
# 1              0.952222
# 2              0.932145
# 3              0.911009
# 4              0.000000
# ...

# %%
len(features["embed_results"])
# Out:
# 21046

# %%
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import MultiLabelBinarizer, StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import MultiLabelBinarizer, StandardScaler, FunctionTransformer

# %%
df_expanded = pd.concat([features.drop(['embed_results'], axis=1),
                         features['embed_results'].apply(pd.Series)], axis=1)

# Шаг 2: Развертывание списка категорий
df_expanded['categories'] = df_expanded['categories'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else [])

# Шаг 3: Развертывание 'avg_embedding' на отдельные столбцы
embedding_df = df_expanded['avg_embedding'].apply(pd.Series)
embedding_df.columns = [f'avg_embedding_{i}' for i in embedding_df.columns]
df_expanded = pd.concat([df_expanded.drop(['avg_embedding'], axis=1), embedding_df], axis=1)

# Если нужно использовать 'max_pooling_embedding', аналогично:
# max_pooling_embedding_df = df_expanded['max_pooling_embedding'].apply(pd.Series)
# max_pooling_embedding_df.columns = [f'max_pooling_embedding_{i}' for i in max_pooling_embedding_df.columns]
# df_expanded = pd.concat([df_expanded.drop(['max_pooling_embedding'], axis=1), max_pooling_embedding_df], axis=1)

# Теперь DataFrame готов для дальнейшей обработки
print("Развернутый DataFrame:")
print(df_expanded.head())
# Out:
# Развернутый DataFrame:
#        vk_id  average_distance                              categories  \
# 1  133343174          0.952222       [Extremism, Environment, Erotics]
# 2  164421917          0.932145         [Hobbies, Erotics, Environment]
# 3  476302530          0.911009       [Hobbies, Erotics, Entertainment]
# 4  311097298          0.000000  [Education, Entertainment, Technology]
# 5  261985066          0.931702       [Politics, Environment, Violence]
#
#    diversity                               max_pooled_embedding  \
# 1   0.855860  [0.013045457191765308, 0.013555492274463177, 0...
# 2   0.000000  [-0.023628689348697662, 0.03252067789435387, 0...
# 3   0.846211  [0.013649879954755306, 0.007465928327292204, 0...
# 4   0.828415  [0.003146857488900423, 0.04890161007642746, 0....
# 5   0.806725  [0.020681021735072136, 0.02414199523627758, 0....
#
#    avg_embedding_0  avg_embedding_1  avg_embedding_2  avg_embedding_3  \
# ...

# %%
df_expanded

# %%
class MultiLabelBinarizerTransformer(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.mlb = MultiLabelBinarizer()
        
    def fit(self, X, y=None):
        self.mlb.fit(X)
        return self
    
    def transform(self, X):
        return self.mlb.transform(X)
    
    def get_feature_names_out(self, input_features=None):
        return self.mlb.classes_

# %%
rofl = MultilabelBinarizerTransformer()
rofl.

# %%
# Шаг 4: Создание пользовательского трансформера для извлечения эмбеддингов
class EmbeddingExtractor(BaseEstimator, TransformerMixin):
    def __init__(self, columns):
        self.columns = columns
        
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        return X[self.columns].values

# Определяем имена столбцов эмбеддингов
embedding_columns = [col for col in df_expanded.columns if col.startswith('avg_embedding_')]

# Определяем колонку для категорий и остальные числовые признаки
categorical_features = ['categories']
numerical_features = ['diversity', "average_distance"]

# Создаем колонный трансформер для предварительной обработки
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', MultiLabelBinarizerTransformer(), 'categories'),
        ('num', Pipeline([
            ('log1p', FunctionTransformer(np.log1p, validate=True)),
            ('scaler', StandardScaler())
        ]), numerical_features),
        ('embed', Pipeline([
            ('extract', 'passthrough'),  # Убедимся, что эмбеддинги проходят через пайплайн
            ('scaler', StandardScaler()),
            ('pca', PCA(n_components=1))  # Первый PCA для эмбеддингов
        ]), embedding_columns)
    ],
    remainder='drop'  # Удаляем другие столбцы
)

# Создаем полный пайплайн
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('pca', PCA(n_components=3)),  # Второй PCA для всех признаков вместе
    ('cluster', KMeans(n_clusters=2, random_state=42))
])

# Подготовка данных
X = df_expanded # .drop(['average_distance'], axis=1)  # Предполагаем, что 'average_distance' не используется

# Обучение пайплайна
pipeline.fit(X)

# Предсказание кластеров
clusters = pipeline.predict(X)

# Добавляем кластеры в DataFrame
df_expanded['cluster'] = clusters

print("\nDataFrame с кластеризацией:")
print(df_expanded.head())
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# DataFrame с кластеризацией:
#        vk_id  average_distance                              categories  \
# 1  133343174          0.952222       [Extremism, Environment, Erotics]
# 2  164421917          0.932145         [Hobbies, Erotics, Environment]
# 3  476302530          0.911009       [Hobbies, Erotics, Entertainment]
# 4  311097298          0.000000  [Education, Entertainment, Technology]
# 5  261985066          0.931702       [Politics, Environment, Violence]
#
#    diversity                               max_pooled_embedding  \
# 1   0.855860  [0.013045457191765308, 0.013555492274463177, 0...
# 2   0.000000  [-0.023628689348697662, 0.03252067789435387, 0...
# 3   0.846211  [0.013649879954755306, 0.007465928327292204, 0...
# ...

# %%
df_expanded
# Out:
#            vk_id  average_distance                              categories  \
# 1      133343174          0.952222       [Extremism, Environment, Erotics]
# 2      164421917          0.932145         [Hobbies, Erotics, Environment]
# 3      476302530          0.911009       [Hobbies, Erotics, Entertainment]
# 4      311097298          0.000000  [Education, Entertainment, Technology]
# 5      261985066          0.931702       [Politics, Environment, Violence]
# ...          ...               ...                                     ...
# 21115  505137620          0.000000        [Education, Erotics, Technology]
# 21116  495644176          0.932295       [Erotics, Extremism, Environment]
# 21117  256485116          0.959110          [Education, Erotics, Business]
# 21118  390326578          0.935045             [Extremism, Erotics, Crime]
# 21119  441298535          0.000000          [Business, Extremism, Erotics]
#
# ...

# %%
df_expanded[df_expanded["vk_id"]=='133343174']["cluster"].loc[1]
# Out:
# 1

# %%
user_new[user_new["vk_id"]=='133343174']["groups_names"].loc[1]
# Out:
# 'Рифмы и Панчи; NR; Берегите нервы, я мужчина-стерва; The Devil Within; Атеист; d o p e; лефортово.; S ∆ Σ N T S; MENTHOL; DEPSIDASE; Touch; Библиотека программиста; CROMULENT; налейте женщине водяры; Saturation; плохой день; NCS; че; INTΣRΔCTIVΣ; Латынь для Пацанов; EA7 | MUSIC |; d r u g s; 9O2; Отрывки из книг. Библиотека знаний; Злая Реальность; Книжный дух; Литература; Сохранить к себе; picsave; Экселент; прекрасно; lofi hip hop / russian community; ТАТУИРОВКИ; Art of Depressive; Языки программирования: Python, Java, JS, PHP…; BERSSERKER'

# %%
df_expanded[df_expanded["vk_id"]=='261985066']["cluster"].loc[5]
# Out:
# 0

# %%
user_new[user_new["vk_id"]=='261985066']["groups_names"].loc[5]
# Out:
# 'женские форумы; Пиццерия Залупинск; Леонардо Дайвинчик; проект разгром; бля я так хочу в лес; Уличные Драки | ММА | Юмор; фотограф великий новгород・lance_fm; Пуньк; Pornmap; Т.У.Д .©; КТО ПО ЖИЗНИ; ✹на движениях✹; A L C A T R A Z; Гараж 54; Книга животных; Скандинавская одежда Викинг | VIKING; вы дошли до конца internet; коты в необычных местах; Radio 1 Dance; Steam Reviews; ПАТРИОТЫ | РОССИЯ !!!; Мемы про ХОХЛОВ; Тайная жизнь вашего кота; Древний Рим: Res publica Romana; Vocal Drum and Bass; ПИЛОТКА; неинтересные видео с камер наблюдения; STUDIO 21; Угол милитариста; Top Gear & The Grand Tour на ITOP-GEAR.RU; Общество Радикальной ТреZвости (ОРТ); Отсталые в развитии коты; ave, cat; HISTОРИЯ®; Den Be Love; VALVe MEMES; БИОЛОГ; Эра VHS. 80-е 90-е 00-е Лучшее время!; Средневековье; Adeptus Historicus | Basilica; 1373 from hell; Югославская Мемная Республика | ЮМР; Историческая Парадоксия; Всё о Швейцарии!; КАПС ДОБРОТА ЛЮБОВЬ МИР; История Древнего Рима / History of Rome; OGGSAY; Толст
# ...

# %%
df_expanded.describe()
# Out:
#        average_distance     diversity  avg_embedding_0  avg_embedding_1  \
# count      21046.000000  21046.000000     21046.000000     21046.000000
# mean           0.716162      0.800220        -0.001959        -0.006932
# std            0.407467      0.148687         0.014150         0.011891
# min            0.000000      0.000000        -0.075285        -0.078140
# 25%            0.842657      0.804143        -0.010851        -0.014484
# 50%            0.939072      0.824862        -0.002353        -0.006786
# 75%            0.962159      0.845207         0.006617         0.000770
# max            1.000000      1.000000         0.102056         0.062301
#
#        avg_embedding_2  avg_embedding_3  avg_embedding_4  avg_embedding_5  \
# count     21046.000000     21046.000000     21046.000000     21046.000000
# mean          0.028722         0.009267         0.010600        -0.010068
# std           0.011686         0.013106         0.012889         0.013195
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df_expanded['average_distance'], bins=30, kde=True, stat='density', color='blue', alpha=0.5)
plt.title('Гистограмма распределения с KDE')
plt.xlabel('Значения')
plt.ylabel('Плотность')
plt.grid(axis='y')  # Ограничиваем ось X от 0 до 1
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df_expanded["diversity"].corr(df_expanded["average_distance"])
# Out:
# 0.1517239068139017

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA

# %%
X
# Out:
#                                    categories  diversity  \
# 1           [Extremism, Environment, Erotics]   0.855860
# 2             [Hobbies, Erotics, Environment]   0.000000
# 3           [Hobbies, Erotics, Entertainment]   0.846211
# 4      [Education, Entertainment, Technology]   0.828415
# 5           [Politics, Environment, Violence]   0.806725
# ...                                       ...        ...
# 21115        [Education, Erotics, Technology]   0.000000
# 21116       [Erotics, Extremism, Environment]   0.822381
# 21117          [Education, Erotics, Business]   0.783261
# 21118             [Extremism, Erotics, Crime]   0.792962
# 21119          [Business, Extremism, Erotics]   0.809703
#
#                                     max_pooled_embedding  avg_embedding_0  \
# 1      [0.013045457191765308, 0.013555492274463177, 0...        -0.002316
# 2      [-0.023628689348697662, 0.03252067789435387, 0...        -0.023629
# ...

# %%
X_preprocessed = pipeline.named_steps['preprocessor'].transform(X)

# Применим PCA для визуализации
pca_vis = PCA(n_components=2, random_state=42)
X_pca_vis = pca_vis.fit_transform(X_preprocessed)

# %%
df_vis = pd.DataFrame({
    'PCA1': X_pca_vis[:, 0],
    'PCA2': X_pca_vis[:, 1],
    'Cluster': df_expanded['cluster']
})

print(df_vis.head())
# Out:
#        PCA1      PCA2  Cluster
# 1 -0.672022  0.160084        1
# 2  3.426458  4.208379        0
# 3 -0.563132  0.162065        1
# 4  1.144825 -1.345407        0
# 5 -0.435297  0.326980        1

# %%
# Настройка стиля графиков
sns.set(style="whitegrid")

# Создаем фигуру и оси
plt.figure(figsize=(10, 7))

# Создаем scatter plot с цветом по кластерам
palette = sns.color_palette("bright", np.unique(df_vis['Cluster']).shape[0])

sns.scatterplot(
    data=df_vis,
    x='PCA1',
    y='PCA2',
    hue='Cluster',
    palette=palette,
    alpha=0.7,
    s=100
)

# Добавляем заголовок и подписи осей
plt.title('Кластеризация с использованием PCA (2D visualization)', fontsize=16)
plt.xlabel('Компонент PCA 1', fontsize=14)
plt.ylabel('Компонент PCA 2', fontsize=14)

# Добавляем легенду
plt.legend(title='Кластер', fontsize=12, title_fontsize=14)

# Отображаем график
plt.show()

# %%
df_expanded
# Out:
#        average_distance                              categories  diversity  \
# 1              0.952222       [Extremism, Environment, Erotics]   0.855860
# 2              0.932145         [Hobbies, Erotics, Environment]   0.000000
# 3              0.911009       [Hobbies, Erotics, Entertainment]   0.846211
# 4              0.000000  [Education, Entertainment, Technology]   0.828415
# 5              0.931702       [Politics, Environment, Violence]   0.806725
# ...                 ...                                     ...        ...
# 21115          0.000000        [Education, Erotics, Technology]   0.000000
# 21116          0.932295       [Erotics, Extremism, Environment]   0.822381
# 21117          0.959110          [Education, Erotics, Business]   0.783261
# 21118          0.935045             [Extremism, Erotics, Crime]   0.792962
# 21119          0.000000          [Business, Extremism, Erotics]   0.809703
#
# ...
